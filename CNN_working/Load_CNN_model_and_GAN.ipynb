# %% [markdown]
# This Kernel for someone want to deep dive into image classification. I use CNN for classification model. If you found this Kernel helpful please up vote it. If you have some feedback and question don't forget to comment below.
#
# I have simplier model with
# * https://www.kaggle.com/uysimty/get-start-image-classification

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd 
import os
os.environ["CUDA_VISIBLE_DEVICES"]="4"; 

from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random


import tensorflow as tf
from keras import backend as K
tf.debugging.set_log_device_placement(True)
# Out:
# Using TensorFlow backend.
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Define Constants

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Prepare Traning Data

# %%
df = pd.read_csv("../ISICArchive_Detail.csv")

# %%
df_data = df[(df["meta-clinical-diagnosis"]=="nevus") | (df["meta-clinical-diagnosis"]=="melanoma")]

# %%
df_data
# Out:
#                             _id          name _modelType  \
# 0      5436e3abbae478396759f0cf  ISIC_0000000      image
# 1      5436e3acbae478396759f0d1  ISIC_0000001      image
# 2      5436e3acbae478396759f0d3  ISIC_0000002      image
# 3      5436e3acbae478396759f0d5  ISIC_0000003      image
# 4      5436e3acbae478396759f0d7  ISIC_0000004      image
# 5      5436e3acbae478396759f0d9  ISIC_0000005      image
# 6      5436e3acbae478396759f0db  ISIC_0000006      image
# 7      5436e3acbae478396759f0dd  ISIC_0000007      image
# 8      5436e3acbae478396759f0df  ISIC_0000008      image
# 9      5436e3acbae478396759f0e1  ISIC_0000009      image
# 10     5436e3acbae478396759f0e3  ISIC_0000010      image
# 11     5436e3acbae478396759f0e5  ISIC_0000011      image
# 12     5436e3acbae478396759f0e7  ISIC_0000012      image
# 13     5436e3adbae478396759f0e9  ISIC_0000013      image
# 14     5436e3adbae478396759f0eb  ISIC_0000014      image
# 15     5436e3adbae478396759f0ed  ISIC_0000015      image
# 16     5436e3adbae478396759f0ef  ISIC_0000016      image
# 17     5436e3adbae478396759f0f1  ISIC_0000017      image
# 18     5436e3adbae478396759f0f3  ISIC_0000018      image
# 19     5436e3adbae478396759f0f5  ISIC_0000019      image
# 20     5436e3adbae478396759f0f7  ISIC_0000020      image
# 21     5436e3adbae478396759f0f9  ISIC_0000021      image
# 22     5436e3aebae478396759f0fb  ISIC_0000022      image
# 23     5436e3aebae478396759f0fd  ISIC_0000023      image
# 24     5436e3aebae478396759f0ff  ISIC_0000024      image
# 25     5436e3aebae478396759f101  ISIC_0000025      image
# 26     5436e3aebae478396759f103  ISIC_0000026      image
# 27     5436e3aebae478396759f105  ISIC_0000027      image
# 28     5436e3aebae478396759f107  ISIC_0000028      image
# 29     5436e3aebae478396759f109  ISIC_0000029      image
# 23903    User 5KJX                 dermoscopic                      30.0
# 23904    User 5KJX                 dermoscopic                      25.0
# 23905    User 6YB2                    clinical                      80.0
#
#        meta-acquisition-pixelsX meta-clinical-anatom_site_general  \
# 0                          1022                    anterior torso
# 1                          1022                    anterior torso
# 2                          1022                   upper extremity
# 3                          1022                   upper extremity
# 4                          1022                   posterior torso
# 5                          1022                    anterior torso
# 6                          1022                   posterior torso
# 7                          1022                   posterior torso
# 8                          1022                    anterior torso
# 9                          1022                    anterior torso
# 10                         1022                   posterior torso
# 11                         1022                   lower extremity
# 12                         1022                   posterior torso
# 13                         1022                   posterior torso
# 14                         1022                   posterior torso
# 15                         1022                   posterior torso
# 16                         1022                    anterior torso
# 17                         1504                   posterior torso
# 18                         1504                   posterior torso
# 19                         1504                   posterior torso
# 20                         1504                    anterior torso
# 21                         1504                   posterior torso
# 22                         1504                   lower extremity
# 23                         1504                    anterior torso
# 24                         1504                   posterior torso
# 25                         1504                   lower extremity
# 26                         1504                   lower extremity
# 27                         1504                    anterior torso
# 28                         1504                    anterior torso
# 29                         1504                   posterior torso
# ...                         ...                               ...
# 23869                       600                   lower extremity
# 23870                       600                   upper extremity
# 23871                       600                   lower extremity
# 23872                       600                               NaN
# 23873                       600                   posterior torso
# 23874                       600                   posterior torso
# 23876                       600                   lower extremity
# 23877                       600                   lower extremity
# 23878                       600                   posterior torso
# 23879                       600                   lower extremity
# 23881                       600                   lower extremity
# 23882                       600                         head/neck
# 23884                       600                   posterior torso
# 23885                       600                   lower extremity
# 23886                       600                               NaN
# 23888                       600                   posterior torso
# 23889                       600                   upper extremity
# 23891                       600                   posterior torso
# 23892                       600                   upper extremity
# 23893                       600                               NaN
# 23894                       600                   posterior torso
# 23895                       600                   posterior torso
# 23896                       600                               NaN
# 23897                       600                   lower extremity
# 23898                       600                    anterior torso
# 23900                       600                   upper extremity
# 23901                       600                   lower extremity
# 23903                       600                               NaN
# 23904                       600                    anterior torso
# 23905                      2880                               NaN
#
#        meta-acquisition-pixelsY meta-clinical-benign_malignant  \
# 0                           767                         benign
# 1                           767                         benign
# 2                           767                      malignant
# 3                           767                         benign
# 4                           767                      malignant
# 5                           767                         benign
# 6                           767                         benign
# 7                           767                         benign
# 8                           767                         benign
# 9                           767                         benign
# 10                          767                         benign
# 11                          767                         benign
# 12                          767                         benign
# 13                          767                      malignant
# 14                          767                         benign
# 15                          767                         benign
# 16                          767                         benign
# 17                         1129                         benign
# 18                         1129                         benign
# 19                         1129                         benign
# 20                         1129                         benign
# 21                         1129                         benign
# 22                         1129                      malignant
# 23                         1129                         benign
# 24                         1129                         benign
# 25                         1129                         benign
# 26                         1129                      malignant
# 27                         1129                         benign
# 28                         1129                         benign
# 29                         1129                      malignant
# ...                         ...                            ...
# 23869                       450                         benign
# 23870                       450                         benign
# 23871                       450                      malignant
# 23872                       450                         benign
# 23873                       450                      malignant
# 23874                       450                         benign
# 23876                       450                         benign
# 23877                       450                         benign
# 23878                       450                      malignant
# 23879                       450                         benign
# 23881                       450                         benign
# 23882                       450                         benign
# 23884                       450                         benign
# 23885                       450                         benign
# 23886                       450                         benign
# 23888                       450                         benign
# 23889                       450                         benign
# 23891                       450                         benign
# 23892                       450                         benign
# 23893                       450                         benign
# 23894                       450                         benign
# 23895                       450                         benign
# 23896                       450                         benign
# 23897                       450                      malignant
# 23898                       450                         benign
# 23900                       450                      malignant
# 23901                       450                      malignant
# 23903                       450                         benign
# 23904                       450                         benign
# 23905                      1800                      malignant
#
#       meta-clinical-diagnosis meta-clinical-diagnosis_confirm_type  \
# 0                       nevus                                  NaN
# 1                       nevus                                  NaN
# 2                    melanoma                       histopathology
# 3                       nevus                                  NaN
# 4                    melanoma                       histopathology
# 5                       nevus                                  NaN
# 6                       nevus                                  NaN
# 7                       nevus                                  NaN
# 8                       nevus                                  NaN
# 9                       nevus                                  NaN
# 10                      nevus                                  NaN
# 11                      nevus                                  NaN
# 12                      nevus                                  NaN
# 13                   melanoma                       histopathology
# 14                      nevus                                  NaN
# 15                      nevus                                  NaN
# 16                      nevus                                  NaN
# 17                      nevus                                  NaN
# 18                      nevus                                  NaN
# 19                      nevus                                  NaN
# 20                      nevus                                  NaN
# 21                      nevus                                  NaN
# 22                   melanoma                       histopathology
# 23                      nevus                                  NaN
# 24                      nevus                                  NaN
# 25                      nevus                                  NaN
# 26                   melanoma                       histopathology
# 27                      nevus                                  NaN
# 28                      nevus                                  NaN
# 29                   melanoma                       histopathology
# ...                       ...                                  ...
# 23869                   nevus                       histopathology
# 23870                   nevus                       histopathology
# 23871                melanoma                       histopathology
# 23872                   nevus                       histopathology
# 23873                melanoma                       histopathology
# 23874                   nevus                       histopathology
# 23876                   nevus                       histopathology
# 23877                   nevus                       histopathology
# 23878                melanoma                       histopathology
# 23879                   nevus                       histopathology
# 23881                   nevus                       histopathology
# 23882                   nevus                       histopathology
# 23884                   nevus                       histopathology
# 23885                   nevus                       histopathology
# 23886                   nevus        single image expert consensus
# 23888                   nevus                       histopathology
# 23889                   nevus                       histopathology
# 23891                   nevus                       histopathology
# 23892                   nevus                       histopathology
# 23893                   nevus        single image expert consensus
# 23894                   nevus                       histopathology
# 23895                   nevus                       histopathology
# 23896                   nevus        single image expert consensus
# 23897                melanoma                       histopathology
# 23898                   nevus                       histopathology
# 23900                melanoma                       histopathology
# 23901                melanoma                       histopathology
# 23903                   nevus                       histopathology
# 23904                   nevus                       histopathology
# 23905                melanoma                       histopathology
#
#       meta-clinical-melanocytic meta-clinical-sex
# 0                          True            female
# 1                          True            female
# 2                          True            female
# 3                          True              male
# 4                          True              male
# 5                          True            female
# 6                          True            female
# 7                          True            female
# 8                          True            female
# 9                          True            female
# 10                         True            female
# 11                         True            female
# 12                         True              male
# 13                         True            female
# 14                         True              male
# 15                         True              male
# 16                         True            female
# 17                         True            female
# 18                         True              male
# 19                         True            female
# 20                         True            female
# 21                         True            female
# 22                         True            female
# 23                         True            female
# 24                         True              male
# 25                         True            female
# 26                         True            female
# 27                         True            female
# 28                         True              male
# 29                         True            female
# ...                         ...               ...
# 23869                      True            female
# 23870                      True              male
# 23871                      True              male
# 23872                      True              male
# 23873                      True            female
# 23874                      True            female
# 23876                      True            female
# 23877                      True            female
# 23878                      True            female
# 23879                      True              male
# 23881                      True              male
# 23882                      True              male
# 23884                      True              male
# 23885                      True            female
# 23886                      True            female
# 23888                      True              male
# 23889                      True              male
# 23891                      True              male
# 23892                      True              male
# 23893                      True              male
# 23894                      True              male
# 23895                      True              male
# 23896                      True            female
# 23897                      True              male
# 23898                      True              male
# 23900                      True              male
# 23901                      True            female
# 23903                      True              male
# 23904                      True            female
# 23905                      True              male
#
# [20735 rows x 16 columns]

# %%
############ df_data  사용될 전체 메타 원본 데이터
df_data_use = df_data.copy()

# %%
columns = ["_id", "_modelType", "created","creator-_id", "creator-name", "meta-acquisition-image_type", "meta-clinical-age_approx" \
          ,"meta-acquisition-pixelsX","meta-clinical-anatom_site_general","meta-acquisition-pixelsY","meta-clinical-benign_malignant" \
          ,"meta-clinical-diagnosis_confirm_type","meta-clinical-melanocytic","meta-clinical-sex"]
df_data_use.drop(columns, inplace=True, axis=1)

# %% [markdown]
# ### See Total In count

# %%
df_data_use['meta-clinical-diagnosis'].value_counts().plot.bar()

# %% [markdown]
# From our data we have   {'nevus': 18566, 'melanoma': 2169}

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Input Layer**: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
# * **Conv Layer**: This layer will extract features from image.
# * **Pooling Layer**: This layerreduce the spatial volume of input image after convolution.
# * **Fully Connected Layer**: It connect the network from a layer to another layer
# * **Output Layer**: It is the predicted values layer.

# %% [markdown]
# # Data Split

# %%
df_data_use =  df_data_use.rename(columns={"meta-clinical-diagnosis": "category"})
df_data_use =  df_data_use.rename(columns={"name": "filename"})
df_data_use["category"] = df_data_use["category"].replace({"nevus": "0",  "melanoma": "1"})

# %%
df_data_use["filename"] = df_data_use["filename"] + ".jpg"

# %%
## SPlit Test / Train data

# %%
df_data_use = df_data_use.reset_index(drop=True)

# %%
df_only_nevus = df_data_use[df_data_use["category"]=="0"]
df_only_melanoma = df_data_use[df_data_use["category"]=="1"]

# %%
np.random.seed(42)

df_test_melanoma = df_only_melanoma.loc \
[np.random.permutation(df_only_melanoma.index)[:500]]

df_test_nevus = df_only_nevus.loc \
[np.random.permutation(df_only_nevus.index)[:500]]


df_train_melanoma = df_only_melanoma.loc \
[np.random.permutation(df_only_melanoma.index)[500:]]

df_train_nevus = df_only_nevus.loc \
[np.random.permutation(df_only_nevus.index)[500:]]

# %%
'''
df_data_use(20735 rows × 2 columns)
##
df_only_nevus(18566 rows × 2 columns)
df_only_melanoma(2169 rows × 2 columns)
##
df_test_nevus(500 rows × 2 columns) 
df_test_melanoma(500 rows × 2 columns)
##
df_train_nevus(18066 rows × 2 columns)
df_train_melanoma (1669 rows × 2 columns)
 '''
# Out:
# '\ndf_data_use(20735 rows × 2 columns)\n##\ndf_only_nevus(18566 rows × 2 columns)\ndf_only_melanoma(2169 rows × 2 columns)\n##\ndf_test_nevus(500 rows × 2 columns) \ndf_test_melanoma(500 rows × 2 columns)\n##\ndf_train_nevus(18066 rows × 2 columns)\ndf_train_melanoma (1669 rows × 2 columns)\n '

# %%
train_frames = [df_train_nevus,df_train_melanoma]
test_frames = [df_test_nevus,df_test_melanoma]

df_trains = pd.concat(train_frames)
df_tests = pd.concat(test_frames)

#df_test = df_only_melanoma.loc \
#        [np.random.permutation(df_only_melanoma.index)[:500]]\
#        | df_only_nevus.loc \
#        [np.random.permutation(df_only_nevus.index)[:500]]

# %%
df_trains = df_trains.reindex(np.random.permutation(df_trains.index))
df_trains = df_trains.reset_index(drop=True)

df_tests = df_tests.reindex(np.random.permutation(df_tests.index))
df_tests = df_tests.reset_index(drop=True)

# %%
train_df, validate_df = train_test_split(df_trains, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
print(train_df['category'].value_counts())
print( "nevus: 0,  melanoma: 1")
# Out:
# 0    14461
# 1     1327
# Name: category, dtype: int64
# nevus: 0,  melanoma: 1

# %%
validate_df['category'].value_counts().plot.bar()
print(validate_df['category'].value_counts())
print( "nevus: 0,  melanoma: 1")
# Out:
# 0    3605
# 1     342
# Name: category, dtype: int64
# nevus: 0,  melanoma: 1

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=64

# %% [markdown]
# # Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../ISICArchive/", 
    x_col="filename",
    y_col="category",
    target_size=IMAGE_SIZE,
    class_mode="categorical",
    batch_size=batch_size
)
# Out:
# Found 15788 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../ISICArchive/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 3947 validated image filenames belonging to 2 classes.

# %% [markdown]
# # See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../ISICArchive/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seem to be nice

# %% [markdown]
# # Prepare Testing Data

# %%
#test_filenames = os.listdir("../input/test1/test1")
test_df = pd.DataFrame({
    'filename': df_tests['filename']
})
nb_samples = test_df.shape[0]

# %%
os.environ["HDF5_USE_FILE_LOCKING"]='FALSE';

# %% [markdown]
# # Model define

# %%
#FAST_RUN = False
#IMAGE_WIDTH=128
#IMAGE_HEIGHT=128
#IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
#IMAGE_CHANNELS=3

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes
    
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.models import load_model
model.load_weights('model.h5')

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../ISICArchive/",
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1000 validated image filenames.

# %% [markdown]
# # Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# WARNING:tensorflow:From /home2/kwangsookim/kskim_test/input/all-dogs/venv/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
y_true =  df_tests['category'].to_numpy().astype(int)
y_pred = test_df['category'].to_numpy().astype(int)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
(tn, fp, fn, tp)
# Out:
# (447, 53, 106, 394)

# %%
import seaborn as sn
sn.set(font_scale=1.4)#for label size
sn.heatmap(cm, annot=True,fmt='g')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       500
#            1       0.88      0.79      0.83       500
#
#     accuracy                           0.84      1000
#    macro avg       0.84      0.84      0.84      1000
# weighted avg       0.84      0.84      0.84      1000

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true, y_pred)
auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
predict
# Out:
# array([[8.9214760e-01, 1.0785236e-01],
#        [6.3619494e-01, 3.6380509e-01],
#        [9.2302126e-01, 7.6978758e-02],
#        ...,
#        [9.9939251e-01, 6.0745288e-04],
#        [4.6239299e-01, 5.3760701e-01],
#        [4.6212652e-01, 5.3787357e-01]], dtype=float32)
